# %% [markdown]
# # 利用 Python 存取 API
#
#
# * 了解 Server Client 的架構與溝通方法
# * 知道 HTTP Request & Response 的內容
# * 什麼是 API？如何用 Python 程式存取 API 資料

# %% [markdown]
# ## 作業目標
#
# * 比較一下範例檔案中的「r.text」與「json.loads(r.text)」讀出來的內容有什麼差異
# * 自行尋找一個合適的 API 接口做練習，並且查看其回傳內容
#     * https://cat-fact.herokuapp.com/facts (來源：https://alexwohlbruck.github.io/cat-facts/)
#     * http://odata.wra.gov.tw/v4/RealtimeWaterLevel (來源：https://data.gov.tw/dataset/25768)

# %% [markdown]
# ### 比較一下範例檔案中的「r.text」與「json.loads(r.text)」讀出來的內容有什麼差異

# %% [markdown]
# ### r.text

# %%
import requests
r = requests.get('https://api.github.com/events')
r.text
# Out:
# '[{"id":"10976988740","type":"IssuesEvent","actor":{"id":21153554,"login":"rumboalla","display_login":"rumboalla","gravatar_id":"","url":"https://api.github.com/users/rumboalla","avatar_url":"https://avatars.githubusercontent.com/u/21153554?"},"repo":{"id":66190491,"name":"rumboalla/apkupdater","url":"https://api.github.com/repos/rumboalla/apkupdater"},"payload":{"action":"closed","issue":{"url":"https://api.github.com/repos/rumboalla/apkupdater/issues/246","repository_url":"https://api.github.com/repos/rumboalla/apkupdater","labels_url":"https://api.github.com/repos/rumboalla/apkupdater/issues/246/labels{/name}","comments_url":"https://api.github.com/repos/rumboalla/apkupdater/issues/246/comments","events_url":"https://api.github.com/repos/rumboalla/apkupdater/issues/246/events","html_url":"https://github.com/rumboalla/apkupdater/issues/246","id":254805892,"node_id":"MDU6SXNzdWUyNTQ4MDU4OTI=","number":246,"title":"Add check for updates on start","user":{"login":"oroboros","id":1668665,"node_id":"MDQ6VXNlcjE2Njg2NjU=","avatar_url":"https://avatars0.githubusercontent.com/u/1668665?v=4","gravatar_id":"","url":"https://api.github.com/users/oroboros","html_url":"https://github.com/oroboros","followers_url":"https://api.github.com/users/oroboros/followers","following_url":"https://api.github.com/users/oroboros/following{/other_user}","gists_url":"https://api.github.com/users/oroboros/gists{/gist_id}","starred_url":"https://api.github.com/users/oroboros/starred{/owner}{/repo}","subscriptions_url":"https://api.github.com/users/oroboros/subscriptions","organizations_url":"https://api.github.com/users/oroboros/orgs","repos_url":"https://api.github.com/users/oroboros/repos","events_url":"https://api.github.com/users/oroboros/events{/privacy}","received_events_url":"https://api.github.com/users/oroboros/received_events","type":"User","site_admin":false},"labels":[],"state":"closed","locked":false,"assignee":null,"assignees":[],"milestone":null,"comments":0,"created_at":"2017-09-02T11:21:29Z","updated_at":"2019-11-29T15:25:06Z","closed_at":"2019-11-29T15:25:06Z","author_association":"NONE","body":"When using APK Updater on Android TV (like Mibox), it is not possible to reach the update icon. It would be useful (for everyone) to have an optional setting to \\"Check for updates on app start.\\""}},"public":true,"created_at":"2019-11-29T15:25:06Z"},{"id":"10976988736","type":"PushEvent","actor":{"id":273367,"login":"kba","display_login":"kba","gravatar_id":"","url":"https://api.github.com/users/kba","avatar_url":"https://avatars.githubusercontent.com/u/273367?"},"repo":{"id":224877857,"name":"OCR-D/ocrd_typegroups_classifier","url":"https://api.github.com/repos/OCR-D/ocrd_typegroups_classifier"},"payload":{"push_id":4336392339,"size":6,"distinct_size":6,"ref":"refs/heads/master","head":"0793e6197c1bd7a2ddd3a098938e224eb43dfbf5","before":"245be86af76826bb3e7d1c5b2cfe638b6395d30c","commits":[{"sha":"86c53887bb61ead85ad501c347ef20cebad99448","author":{"email":"mike.gerber@sbb.spk-berlin.de","name":"Gerber, Mike"},"message":"🐛 Pass down page id","distinct":true,"url":"https://api.github.com/repos/OCR-D/ocrd_typegroups_classifier/commits/86c53887bb61ead85ad501c347ef20cebad99448"},{"sha":"9db17ef9eefde362e9f7784e62991eb1743c16df","author":{"email":"38561704+bertsky@users.noreply.github.com","name":"Robert Sachunsky"},"message":"use image_from_page:\\n\\n- replace deprecated `workspace.resolve_image_as_pil` with `workspace.image_from_page`\\r\\n- use output file ID based by replacing input file ID (or, if still clashing, by counting) instead of concatenation\\r\\n- add xml file extension to output\\r\\n- pass pageId to output\\r\\n- use pageId for logging","distinct":true,"url":"https://api.github.com/repos/OCR-D/ocrd_typegroups_classifier/commits/9db17ef9eefde362e9f7784e62991eb1743c16df"},{"sha":"df2fe90ddddca39683f1c981ae54b8aecec7343b","author":{"email":"unixprog@gmail.com","name":"Konstantin Baierer"},"message":":package: update and prune requi ...

# %%
type(r.text)
# Out:
# str

# %% [markdown]
# ### json.loads(r.text)

# %%
import json
json.loads(r.text)
# Out:
# [{'id': '10976988740',
#   'type': 'IssuesEvent',
#   'actor': {'id': 21153554,
#    'login': 'rumboalla',
#    'display_login': 'rumboalla',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/rumboalla',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/21153554?'},
#   'repo': {'id': 66190491,
#    'name': 'rumboalla/apkupdater',
#    'url': 'https://api.github.com/repos/rumboalla/apkupdater'},
#   'payload': {'action': 'closed',
#    'issue': {'url': 'https://api.github.com/repos/rumboalla/apkupdater/issues/246',
#     'repository_url': 'https://api.github.com/repos/rumboalla/apkupdater',
#     'labels_url': 'https://api.github.com/repos/rumboalla/apkupdater/issues/246/labels{/name}',
#     'comments_url': 'https://api.github.com/repos/rumboalla/apkupdater/issues/246/comments',
#     'events_url': 'https://api.github.com/repos/rumboalla/apkupdater/issues/246/events',
#     'html_url': 'https://github.com/rumboalla/apkupdater/issues/246',
#     'id': 254805892,
#     'node_id': 'MDU6SXNzdWUyNTQ4MDU4OTI=',
#     'number': 246,
#     'title': 'Add check for updates on start',
#     'user': {'login': 'oroboros',
#      'id': 1668665,
#      'node_id': 'MDQ6VXNlcjE2Njg2NjU=',
#      'avatar_url': 'https://avatars0.githubusercontent.com/u/1668665?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/oroboros',
#      'html_url': 'https://github.com/oroboros',
#      'followers_url': 'https://api.github.com/users/oroboros/followers',
#      'following_url': 'https://api.github.com/users/oroboros/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/oroboros/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/oroboros/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/oroboros/subscriptions',
#      'organizations_url': 'https://api.github.com/users/oroboros/orgs',
#      'repos_url': 'https://api.github.com/users/oroboros/repos',
#      'events_url': 'https://api.github.com/users/oroboros/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/oroboros/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'labels': [],
#     'state': 'closed',
#     'locked': False,
#     'assignee': None,
#     'assignees': [],
#     'milestone': None,
#     'comments': 0,
#     'created_at': '2017-09-02T11:21:29Z',
#     'updated_at': '2019-11-29T15:25:06Z',
#     'closed_at': '2019-11-29T15:25:06Z',
#     'author_association': 'NONE',
#     'body': 'When using APK Updater on Android TV (like Mibox), it is not possible to reach the update icon. It would be useful (for everyone) to have an optional setting to "Check for updates on app start."'}},
#   'public': True,
#   'created_at': '2019-11-29T15:25:06Z'},
#  {'id': '10976988736',
#   'type': 'PushEvent',
#   'actor': {'id': 273367,
#    'login': 'kba',
#    'display_login': 'kba',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/kba',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/273367?'},
#   'repo': {'id': 224877857,
#    'name': 'OCR-D/ocrd_typegroups_classifier',
#    'url': 'https://api.github.com/repos/OCR-D/ocrd_typegroups_classifier'},
#   'payload': {'push_id': 4336392339,
#    'size': 6,
#    'distinct_size': 6,
#    'ref': 'refs/heads/master',
#    'head': '0793e6197c1bd7a2ddd3a098938e224eb43dfbf5',
#    'before': '245be86af76826bb3e7d1c5b2cfe638b6395d30c',
#    'commits': [{'sha': '86c53887bb61ead85ad501c347ef20cebad99448',
#      'author': {'email': 'mike.gerber@sbb.spk-berlin.de',
#       'name': 'Gerber, Mike'},
#      'message': '🐛 Pass down page id',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/OCR-D/ocrd_typegroups_classifier/commits/86c53887bb61ead85ad501c347ef20cebad99448'},
#     {'sha': '9db17ef9eefde362e9f7784e62991eb1743c16df',
#      'author': {'email': '38561704+bertsky@users.noreply.github.com',
#       'name': 'Robert Sachunsky'},
#      'message': 'use image_from_page:\n\n- replace deprecated `workspace.resolve_image_as_pil` with `workspace.image_from_page`\r\n- use output file ID based by replacing input file ID (or, if still clashing, by counting) instead of concatenation\r\n- add xml file extension to output\r\n- pass pageId to output\r\n- use pageId for logging',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/OCR-D/ocrd_typegroups_classifier/commits/9db17ef9eefde362e9f7784e62991eb1743c16df'},
#     {'sha': 'df2fe90ddddca39683f1c981ae54b8aecec7343b',
#      'author': {'email': 'unixprog@gmail.com', 'name': 'Konstantin Baierer'},
#      'message': ':package: update and prune requirements',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/OCR-D/ocrd_typegroups_classifier/commits/df2fe90ddddca39683f1c981ae54b8aecec7343b'},
#     {'sha': '5ca5886175f669a0eb92dddd2d4e8489fdb17f9f',
#      'author': {'email': 'unixprog@gmail.com', 'name': 'Konstantin Baierer'},
#      'message': "Merge remote-tracking branch 'mikegerber/fix/pass-down-page-id'",
#      'distinct': True,
#      'url': 'https://api.github.com/repos/OCR-D/ocrd_typegroups_classifier/commits/5ca5886175f669a0eb92dddd2d4e8489fdb17f9f'},
#     {'sha': '369f4e32a602077f89d72b29446c4977e37c123b',
#      'author': {'email': 'unixprog@gmail.com', 'name': 'Konstantin Baierer'},
#      'message': "Merge remote-tracking branch 'bertsky/patch-1'",
#      'distinct': True,
#      'url': 'https://api.github.com/repos/OCR-D/ocrd_typegroups_classifier/commits/369f4e32a602077f89d72b29446c4977e37c123b'},
#     {'sha': '0793e6197c1bd7a2ddd3a098938e224eb43dfbf5',
#      'author': {'email': 'unixprog@gmail.com', 'name': 'Konstantin Baierer'},
#      'message': "Merge remote-tracking branch 'kba/update-requirements'",
#      'distinct': True,
#      'url': 'https://api.github.com/repos/OCR-D/ocrd_typegroups_classifier/commits/0793e6197c1bd7a2ddd3a098938e224eb43dfbf5'}]},
#   'public': True,
#   'created_at': '2019-11-29T15:25:06Z',
#   'org': {'id': 26362587,
#    'login': 'OCR-D',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/OCR-D',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/26362587?'}},
#  {'id': '10976988729',
#   'type': 'PushEvent',
#   'actor': {'id': 1616850,
#    'login': 'HenrikBengtsson',
#    'display_login': 'HenrikBengtsson',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/HenrikBengtsson',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/1616850?'},
#   'repo': {'id': 162214994,
#    'name': 'UCSF-HPC/wynton-slash2',
#    'url': 'https://api.github.com/repos/UCSF-HPC/wynton-slash2'},
#   'payload': {'push_id': 4336392341,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': '2bf4ea5e68d35e62d6d47e9fe04b892f7cbe53cf',
#    'before': 'dde6e23873f204d64c267a0a194a3ca79c4e0684',
#    'commits': [{'sha': '2bf4ea5e68d35e62d6d47e9fe04b892f7cbe53cf',
#      'author': {'email': 'hb@aroma-project.org', 'name': 'hb'},
#      'message': 'Node status updates (qstat -f -qs uE)',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/UCSF-HPC/wynton-slash2/commits/2bf4ea5e68d35e62d6d47e9fe04b892f7cbe53cf'}]},
#   'public': True,
#   'created_at': '2019-11-29T15:25:06Z',
#   'org': {'id': 16865370,
#    'login': 'UCSF-HPC',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/UCSF-HPC',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/16865370?'}},
#  {'id': '10976988732',
#   'type': 'PullRequestEvent',
#   'actor': {'id': 24195641,
#    'login': 'Karyum',
#    'display_login': 'Karyum',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/Karyum',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/24195641?'},
#   'repo': {'id': 223120904,
#    'name': 'FACN8/Pre-course',
#    'url': 'https://api.github.com/repos/FACN8/Pre-course'},
#   'payload': {'action': 'closed',
#    'number': 11,
#    'pull_request': {'url': 'https://api.github.com/repos/FACN8/Pre-course/pulls/11',
#     'id': 347089326,
#     'node_id': 'MDExOlB1bGxSZXF1ZXN0MzQ3MDg5MzI2',
#     'html_url': 'https://github.com/FACN8/Pre-course/pull/11',
#     'diff_url': 'https://github.com/FACN8/Pre-course/pull/11.diff',
#     'patch_url': 'https://github.com/FACN8/Pre-course/pull/11.patch',
#     'issue_url': 'https://api.github.com/repos/FACN8/Pre-course/issues/11',
#     'number': 11,
#     'state': 'closed',
#     'locked': False,
#     'title': 'Adds a week 2 folder',
#     'user': {'login': 'shiryz',
#      'id': 22002193,
#      'node_id': 'MDQ6VXNlcjIyMDAyMTkz',
#      'avatar_url': 'https://avatars3.githubusercontent.com/u/22002193?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/shiryz',
#      'html_url': 'https://github.com/shiryz',
#      'followers_url': 'https://api.github.com/users/shiryz/followers',
#      'following_url': 'https://api.github.com/users/shiryz/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/shiryz/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/shiryz/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/shiryz/subscriptions',
#      'organizations_url': 'https://api.github.com/users/shiryz/orgs',
#      'repos_url': 'https://api.github.com/users/shiryz/repos',
#      'events_url': 'https://api.github.com/users/shiryz/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/shiryz/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'body': 'Adds a week 2 folder',
#     'created_at': '2019-11-29T15:24:33Z',
#     'updated_at': '2019-11-29T15:25:06Z',
#     'closed_at': '2019-11-29T15:25:06Z',
#     'merged_at': '2019-11-29T15:25:06Z',
#     'merge_commit_sha': '0d2bc4a8f5f009a21fd5fc5593920fd45f3c4666',
#     'assignee': None,
#     'assignees': [],
#     'requested_reviewers': [],
#     'requested_teams': [],
#     'labels': [],
#     'milestone': None,
#     'commits_url': 'https://api.github.com/repos/FACN8/Pre-course/pulls/11/commits',
#     'review_comments_url': 'https://api.github.com/repos/FACN8/Pre-course/pulls/11/comments',
#     'review_comment_url': 'https://api.github.com/repos/FACN8/Pre-course/pulls/comments{/number}',
#     'comments_url': 'https://api.github.com/repos/FACN8/Pre-course/issues/11/comments',
#     'statuses_url': 'https://api.github.com/repos/FACN8/Pre-course/statuses/445c1bb6da2694a36d865b9184a104569b4837d1',
#     'head': {'label': 'FACN8:advanced-js-ws',
#      'ref': 'advanced-js-ws',
#      'sha': '445c1bb6da2694a36d865b9184a104569b4837d1',
#      'user': {'login': 'FACN8',
#       'id': 58026296,
#       'node_id': 'MDEyOk9yZ2FuaXphdGlvbjU4MDI2Mjk2',
#       'avatar_url': 'https://avatars1.githubusercontent.com/u/58026296?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/FACN8',
#       'html_url': 'https://github.com/FACN8',
#       'followers_url': 'https://api.github.com/users/FACN8/followers',
#       'following_url': 'https://api.github.com/users/FACN8/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/FACN8/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/FACN8/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/FACN8/subscriptions',
#       'organizations_url': 'https://api.github.com/users/FACN8/orgs',
#       'repos_url': 'https://api.github.com/users/FACN8/repos',
#       'events_url': 'https://api.github.com/users/FACN8/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/FACN8/received_events',
#       'type': 'Organization',
#       'site_admin': False},
#      'repo': {'id': 223120904,
#       'node_id': 'MDEwOlJlcG9zaXRvcnkyMjMxMjA5MDQ=',
#       'name': 'Pre-course',
#       'full_name': 'FACN8/Pre-course',
#       'private': False,
#       'owner': {'login': 'FACN8',
#        'id': 58026296,
#        'node_id': 'MDEyOk9yZ2FuaXphdGlvbjU4MDI2Mjk2',
#        'avatar_url': 'https://avatars1.githubusercontent.com/u/58026296?v=4',
#        'gravatar_id': '',
#        'url': 'https://api.github.com/users/FACN8',
#        'html_url': 'https://github.com/FACN8',
#        'followers_url': 'https://api.github.com/users/FACN8/followers',
#        'following_url': 'https://api.github.com/users/FACN8/following{/other_user}',
#        'gists_url': 'https://api.github.com/users/FACN8/gists{/gist_id}',
#        'starred_url': 'https://api.github.com/users/FACN8/starred{/owner}{/repo}',
#        'subscriptions_url': 'https://api.github.com/users/FACN8/subscriptions',
#        'organizations_url': 'https://api.github.com/users/FACN8/orgs',
#        'repos_url': 'https://api.github.com/users/FACN8/repos',
#        'events_url': 'https://api.github.com/users/FACN8/events{/privacy}',
#        'received_events_url': 'https://api.github.com/users/FACN8/received_events',
#        'type': 'Organization',
#        'site_admin': False},
#       'html_url': 'https://github.com/FACN8/Pre-course',
#       'description': 'Pre-course materials and workshops',
#       'fork': False,
#       'url': 'https://api.github.com/repos/FACN8/Pre-course',
#       'forks_url': 'https://api.github.com/repos/FACN8/Pre-course/forks',
#       'keys_url': 'https://api.github.com/repos/FACN8/Pre-course/keys{/key_id}',
#       'collaborators_url': 'https://api.github.com/repos/FACN8/Pre-course/collaborators{/collaborator}',
#       'teams_url': 'https://api.github.com/repos/FACN8/Pre-course/teams',
#       'hooks_url': 'https://api.github.com/repos/FACN8/Pre-course/hooks',
#       'issue_events_url': 'https://api.github.com/repos/FACN8/Pre-course/issues/events{/number}',
#       'events_url': 'https://api.github.com/repos/FACN8/Pre-course/events',
#       'assignees_url': 'https://api.github.com/repos/FACN8/Pre-course/assignees{/user}',
#       'branches_url': 'https://api.github.com/repos/FACN8/Pre-course/branches{/branch}',
#       'tags_url': 'https://api.github.com/repos/FACN8/Pre-course/tags',
#       'blobs_url': 'https://api.github.com/repos/FACN8/Pre-course/git/blobs{/sha}',
#       'git_tags_url': 'https://api.github.com/repos/FACN8/Pre-course/git/tags{/sha}',
#       'git_refs_url': 'https://api.github.com/repos/FACN8/Pre-course/git/refs{/sha}',
#       'trees_url': 'https://api.github.com/repos/FACN8/Pre-course/git/trees{/sha}',
#       'statuses_url': 'https://api.github.com/repos/FACN8/Pre-course/statuses/{sha}',
#       'languages_url': 'https://api.github.com/repos/FACN8/Pre-course/languages',
#       'stargazers_url': 'https://api.github.com/repos/FACN8/Pre-course/stargazers',
#       'contributors_url': 'https://api.github.com/repos/FACN8/Pre-course/contributors',
#       'subscribers_url': 'https://api.github.com/repos/FACN8/Pre-course/subscribers',
#       'subscription_url': 'https://api.github.com/repos/FACN8/Pre-course/subscription',
#       'commits_url': 'https://api.github.com/repos/FACN8/Pre-course/commits{/sha}',
#       'git_commits_url': 'https://api.github.com/repos/FACN8/Pre-course/git/commits{/sha}',
#       'comments_url': 'https://api.github.com/repos/FACN8/Pre-course/comments{/number}',
#       'issue_comment_url': 'https://api.github.com/repos/FACN8/Pre-course/issues/comments{/number}',
#       'contents_url': 'https://api.github.com/repos/FACN8/Pre-course/contents/{+path}',
#       'compare_url': 'https://api.github.com/repos/FACN8/Pre-course/compare/{base}...{head}',
#       'merges_url': 'https://api.github.com/repos/FACN8/Pre-course/merges',
#       'archive_url': 'https://api.github.com/repos/FACN8/Pre-course/{archive_format}{/ref}',
#       'downloads_url': 'https://api.github.com/repos/FACN8/Pre-course/downloads',
#       'issues_url': 'https://api.github.com/repos/FACN8/Pre-course/issues{/number}',
#       'pulls_url': 'https://api.github.com/repos/FACN8/Pre-course/pulls{/number}',
#       'milestones_url': 'https://api.github.com/repos/FACN8/Pre-course/milestones{/number}',
#       'notifications_url': 'https://api.github.com/repos/FACN8/Pre-course/notifications{?since,all,participating}',
#       'labels_url': 'https://api.github.com/repos/FACN8/Pre-course/labels{/name}',
#       'releases_url': 'https://api.github.com/repos/FACN8/Pre-course/releases{/id}',
#       'deployments_url': 'https://api.github.com/repos/FACN8/Pre-course/deployments',
#       'created_at': '2019-11-21T08:06:23Z',
#       'updated_at': '2019-11-27T05:46:22Z',
#       'pushed_at': '2019-11-29T15:25:05Z',
#       'git_url': 'git://github.com/FACN8/Pre-course.git',
#       'ssh_url': 'git@github.com:FACN8/Pre-course.git',
#       'clone_url': 'https://github.com/FACN8/Pre-course.git',
#       'svn_url': 'https://github.com/FACN8/Pre-course',
#       'homepage': None,
#       'size': 67,
#       'stargazers_count': 1,
#       'watchers_count': 1,
#       'language': None,
#       'has_issues': True,
#       'has_projects': True,
#       'has_downloads': True,
#       'has_wiki': True,
#       'has_pages': False,
#       'forks_count': 1,
#       'mirror_url': None,
#       'archived': False,
#       'disabled': False,
#       'open_issues_count': 4,
#       'license': None,
#       'forks': 1,
#       'open_issues': 4,
#       'watchers': 1,
#       'default_branch': 'master'}},
#     'base': {'label': 'FACN8:master',
#      'ref': 'master',
#      'sha': '70416a462cbc2e8a86e78f0106de288dae60ee45',
#      'user': {'login': 'FACN8',
#       'id': 58026296,
#       'node_id': 'MDEyOk9yZ2FuaXphdGlvbjU4MDI2Mjk2',
#       'avatar_url': 'https://avatars1.githubusercontent.com/u/58026296?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/FACN8',
#       'html_url': 'https://github.com/FACN8',
#       'followers_url': 'https://api.github.com/users/FACN8/followers',
#       'following_url': 'https://api.github.com/users/FACN8/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/FACN8/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/FACN8/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/FACN8/subscriptions',
#       'organizations_url': 'https://api.github.com/users/FACN8/orgs',
#       'repos_url': 'https://api.github.com/users/FACN8/repos',
#       'events_url': 'https://api.github.com/users/FACN8/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/FACN8/received_events',
#       'type': 'Organization',
#       'site_admin': False},
#      'repo': {'id': 223120904,
#       'node_id': 'MDEwOlJlcG9zaXRvcnkyMjMxMjA5MDQ=',
#       'name': 'Pre-course',
#       'full_name': 'FACN8/Pre-course',
#       'private': False,
#       'owner': {'login': 'FACN8',
#        'id': 58026296,
#        'node_id': 'MDEyOk9yZ2FuaXphdGlvbjU4MDI2Mjk2',
#        'avatar_url': 'https://avatars1.githubusercontent.com/u/58026296?v=4',
#        'gravatar_id': '',
#        'url': 'https://api.github.com/users/FACN8',
#        'html_url': 'https://github.com/FACN8',
#        'followers_url': 'https://api.github.com/users/FACN8/followers',
#        'following_url': 'https://api.github.com/users/FACN8/following{/other_user}',
#        'gists_url': 'https://api.github.com/users/FACN8/gists{/gist_id}',
#        'starred_url': 'https://api.github.com/users/FACN8/starred{/owner}{/repo}',
#        'subscriptions_url': 'https://api.github.com/users/FACN8/subscriptions',
#        'organizations_url': 'https://api.github.com/users/FACN8/orgs',
#        'repos_url': 'https://api.github.com/users/FACN8/repos',
#        'events_url': 'https://api.github.com/users/FACN8/events{/privacy}',
#        'received_events_url': 'https://api.github.com/users/FACN8/received_events',
#        'type': 'Organization',
#        'site_admin': False},
#       'html_url': 'https://github.com/FACN8/Pre-course',
#       'description': 'Pre-course materials and workshops',
#       'fork': False,
#       'url': 'https://api.github.com/repos/FACN8/Pre-course',
#       'forks_url': 'https://api.github.com/repos/FACN8/Pre-course/forks',
#       'keys_url': 'https://api.github.com/repos/FACN8/Pre-course/keys{/key_id}',
#       'collaborators_url': 'https://api.github.com/repos/FACN8/Pre-course/collaborators{/collaborator}',
#       'teams_url': 'https://api.github.com/repos/FACN8/Pre-course/teams',
#       'hooks_url': 'https://api.github.com/repos/FACN8/Pre-course/hooks',
#       'issue_events_url': 'https://api.github.com/repos/FACN8/Pre-course/issues/events{/number}',
#       'events_url': 'https://api.github.com/repos/FACN8/Pre-course/events',
#       'assignees_url': 'https://api.github.com/repos/FACN8/Pre-course/assignees{/user}',
#       'branches_url': 'https://api.github.com/repos/FACN8/Pre-course/branches{/branch}',
#       'tags_url': 'https://api.github.com/repos/FACN8/Pre-course/tags',
#       'blobs_url': 'https://api.github.com/repos/FACN8/Pre-course/git/blobs{/sha}',
#       'git_tags_url': 'https://api.github.com/repos/FACN8/Pre-course/git/tags{/sha}',
#       'git_refs_url': 'https://api.github.com/repos/FACN8/Pre-course/git/refs{/sha}',
#       'trees_url': 'https://api.github.com/repos/FACN8/Pre-course/git/trees{/sha}',
#       'statuses_url': 'https://api.github.com/repos/FACN8/Pre-course/statuses/{sha}',
#       'languages_url': 'https://api.github.com/repos/FACN8/Pre-course/languages',
#       'stargazers_url': 'https://api.github.com/repos/FACN8/Pre-course/stargazers',
#       'contributors_url': 'https://api.github.com/repos/FACN8/Pre-course/contributors',
#       'subscribers_url': 'https://api.github.com/repos/FACN8/Pre-course/subscribers',
#       'subscription_url': 'https://api.github.com/repos/FACN8/Pre-course/subscription',
#       'commits_url': 'https://api.github.com/repos/FACN8/Pre-course/commits{/sha}',
#       'git_commits_url': 'https://api.github.com/repos/FACN8/Pre-course/git/commits{/sha}',
#       'comments_url': 'https://api.github.com/repos/FACN8/Pre-course/comments{/number}',
#       'issue_comment_url': 'https://api.github.com/repos/FACN8/Pre-course/issues/comments{/number}',
#       'contents_url': 'https://api.github.com/repos/FACN8/Pre-course/contents/{+path}',
#       'compare_url': 'https://api.github.com/repos/FACN8/Pre-course/compare/{base}...{head}',
#       'merges_url': 'https://api.github.com/repos/FACN8/Pre-course/merges',
#       'archive_url': 'https://api.github.com/repos/FACN8/Pre-course/{archive_format}{/ref}',
#       'downloads_url': 'https://api.github.com/repos/FACN8/Pre-course/downloads',
#       'issues_url': 'https://api.github.com/repos/FACN8/Pre-course/issues{/number}',
#       'pulls_url': 'https://api.github.com/repos/FACN8/Pre-course/pulls{/number}',
#       'milestones_url': 'https://api.github.com/repos/FACN8/Pre-course/milestones{/number}',
#       'notifications_url': 'https://api.github.com/repos/FACN8/Pre-course/notifications{?since,all,participating}',
#       'labels_url': 'https://api.github.com/repos/FACN8/Pre-course/labels{/name}',
#       'releases_url': 'https://api.github.com/repos/FACN8/Pre-course/releases{/id}',
#       'deployments_url': 'https://api.github.com/repos/FACN8/Pre-course/deployments',
#       'created_at': '2019-11-21T08:06:23Z',
#       'updated_at': '2019-11-27T05:46:22Z',
#       'pushed_at': '2019-11-29T15:25:05Z',
#       'git_url': 'git://github.com/FACN8/Pre-course.git',
#       'ssh_url': 'git@github.com:FACN8/Pre-course.git',
#       'clone_url': 'https://github.com/FACN8/Pre-course.git',
#       'svn_url': 'https://github.com/FACN8/Pre-course',
#       'homepage': None,
#       'size': 67,
#       'stargazers_count': 1,
#       'watchers_count': 1,
#       'language': None,
#       'has_issues': True,
#       'has_projects': True,
#       'has_downloads': True,
#       'has_wiki': True,
#       'has_pages': False,
#       'forks_count': 1,
#       'mirror_url': None,
#       'archived': False,
#       'disabled': False,
#       'open_issues_count': 4,
#       'license': None,
#       'forks': 1,
#       'open_issues': 4,
#       'watchers': 1,
#       'default_branch': 'master'}},
#     '_links': {'self': {'href': 'https://api.github.com/repos/FACN8/Pre-course/pulls/11'},
#      'html': {'href': 'https://github.com/FACN8/Pre-course/pull/11'},
#      'issue': {'href': 'https://api.github.com/repos/FACN8/Pre-course/issues/11'},
#      'comments': {'href': 'https://api.github.com/repos/FACN8/Pre-course/issues/11/comments'},
#      'review_comments': {'href': 'https://api.github.com/repos/FACN8/Pre-course/pulls/11/comments'},
#      'review_comment': {'href': 'https://api.github.com/repos/FACN8/Pre-course/pulls/comments{/number}'},
#      'commits': {'href': 'https://api.github.com/repos/FACN8/Pre-course/pulls/11/commits'},
#      'statuses': {'href': 'https://api.github.com/repos/FACN8/Pre-course/statuses/445c1bb6da2694a36d865b9184a104569b4837d1'}},
#     'author_association': 'CONTRIBUTOR',
#     'merged': True,
#     'mergeable': None,
#     'rebaseable': None,
#     'mergeable_state': 'unknown',
#     'merged_by': {'login': 'Karyum',
#      'id': 24195641,
#      'node_id': 'MDQ6VXNlcjI0MTk1NjQx',
#      'avatar_url': 'https://avatars0.githubusercontent.com/u/24195641?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/Karyum',
#      'html_url': 'https://github.com/Karyum',
#      'followers_url': 'https://api.github.com/users/Karyum/followers',
#      'following_url': 'https://api.github.com/users/Karyum/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/Karyum/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/Karyum/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/Karyum/subscriptions',
#      'organizations_url': 'https://api.github.com/users/Karyum/orgs',
#      'repos_url': 'https://api.github.com/users/Karyum/repos',
#      'events_url': 'https://api.github.com/users/Karyum/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/Karyum/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'comments': 0,
#     'review_comments': 0,
#     'maintainer_can_modify': False,
#     'commits': 1,
#     'additions': 0,
#     'deletions': 0,
#     'changed_files': 1}},
#   'public': True,
#   'created_at': '2019-11-29T15:25:06Z',
#   'org': {'id': 58026296,
#    'login': 'FACN8',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/FACN8',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/58026296?'}},
#  {'id': '10976988709',
#   'type': 'PushEvent',
#   'actor': {'id': 533180,
#    'login': 'scriptzteam',
#    'display_login': 'scriptzteam',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/scriptzteam',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/533180?'},
#   'repo': {'id': 153783109,
#    'name': 'scriptzteam/newzNZB-Usenet-Upload-Logger-v1.1',
#    'url': 'https://api.github.com/repos/scriptzteam/newzNZB-Usenet-Upload-Logger-v1.1'},
#   'payload': {'push_id': 4336392327,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': '40b20a288eb6c71a63d7df9452eeffe7166dfa13',
#    'before': 'fa74920cf913b269986685d6e99418262497d6c9',
#    'commits': [{'sha': '40b20a288eb6c71a63d7df9452eeffe7166dfa13',
#      'author': {'email': 'scriptzteam@gmail.com', 'name': 'scriptzteam'},
#      'message': '^^uPdAtE',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/scriptzteam/newzNZB-Usenet-Upload-Logger-v1.1/commits/40b20a288eb6c71a63d7df9452eeffe7166dfa13'}]},
#   'public': True,
#   'created_at': '2019-11-29T15:25:06Z'},
#  {'id': '10976988718',
#   'type': 'IssuesEvent',
#   'actor': {'id': 21153554,
#    'login': 'rumboalla',
#    'display_login': 'rumboalla',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/rumboalla',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/21153554?'},
#   'repo': {'id': 66190491,
#    'name': 'rumboalla/apkupdater',
#    'url': 'https://api.github.com/repos/rumboalla/apkupdater'},
#   'payload': {'action': 'closed',
#    'issue': {'url': 'https://api.github.com/repos/rumboalla/apkupdater/issues/245',
#     'repository_url': 'https://api.github.com/repos/rumboalla/apkupdater',
#     'labels_url': 'https://api.github.com/repos/rumboalla/apkupdater/issues/245/labels{/name}',
#     'comments_url': 'https://api.github.com/repos/rumboalla/apkupdater/issues/245/comments',
#     'events_url': 'https://api.github.com/repos/rumboalla/apkupdater/issues/245/events',
#     'html_url': 'https://github.com/rumboalla/apkupdater/issues/245',
#     'id': 252874168,
#     'node_id': 'MDU6SXNzdWUyNTI4NzQxNjg=',
#     'number': 245,
#     'title': 'Notification not updated nor removed after install',
#     'user': {'login': 'rancidfrog',
#      'id': 6155036,
#      'node_id': 'MDQ6VXNlcjYxNTUwMzY=',
#      'avatar_url': 'https://avatars3.githubusercontent.com/u/6155036?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/rancidfrog',
#      'html_url': 'https://github.com/rancidfrog',
#      'followers_url': 'https://api.github.com/users/rancidfrog/followers',
#      'following_url': 'https://api.github.com/users/rancidfrog/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/rancidfrog/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/rancidfrog/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/rancidfrog/subscriptions',
#      'organizations_url': 'https://api.github.com/users/rancidfrog/orgs',
#      'repos_url': 'https://api.github.com/users/rancidfrog/repos',
#      'events_url': 'https://api.github.com/users/rancidfrog/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/rancidfrog/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'labels': [],
#     'state': 'closed',
#     'locked': False,
#     'assignee': None,
#     'assignees': [],
#     'milestone': None,
#     'comments': 0,
#     'created_at': '2017-08-25T11:35:42Z',
#     'updated_at': '2019-11-29T15:25:06Z',
#     'closed_at': '2019-11-29T15:25:06Z',
#     'author_association': 'NONE',
#     'body': 'App does not update notification of available updates after install.\r\nIt should react somewhat like "download done\' notification, once installed either have notification removed or updated to "x apps updated"\r\nAs seen below, app was updated but notification still shows app update available, which is not the case anymore as state has changed to installed:\r\n![](https://s29.postimg.org/cz9mf8piv/Screenshot_20170824-095232_01.png)'}},
#   'public': True,
#   'created_at': '2019-11-29T15:25:06Z'},
#  {'id': '10976988716',
#   'type': 'PullRequestEvent',
#   'actor': {'id': 4490759,
#    'login': 'wwjiang007',
#    'display_login': 'wwjiang007',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/wwjiang007',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/4490759?'},
#   'repo': {'id': 205892190,
#    'name': 'wwjiang007/delta',
#    'url': 'https://api.github.com/repos/wwjiang007/delta'},
#   'payload': {'action': 'opened',
#    'number': 1,
#    'pull_request': {'url': 'https://api.github.com/repos/wwjiang007/delta/pulls/1',
#     'id': 347089505,
#     'node_id': 'MDExOlB1bGxSZXF1ZXN0MzQ3MDg5NTA1',
#     'html_url': 'https://github.com/wwjiang007/delta/pull/1',
#     'diff_url': 'https://github.com/wwjiang007/delta/pull/1.diff',
#     'patch_url': 'https://github.com/wwjiang007/delta/pull/1.patch',
#     'issue_url': 'https://api.github.com/repos/wwjiang007/delta/issues/1',
#     'number': 1,
#     'state': 'open',
#     'locked': False,
#     'title': '1',
#     'user': {'login': 'wwjiang007',
#      'id': 4490759,
#      'node_id': 'MDQ6VXNlcjQ0OTA3NTk=',
#      'avatar_url': 'https://avatars0.githubusercontent.com/u/4490759?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/wwjiang007',
#      'html_url': 'https://github.com/wwjiang007',
#      'followers_url': 'https://api.github.com/users/wwjiang007/followers',
#      'following_url': 'https://api.github.com/users/wwjiang007/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/wwjiang007/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/wwjiang007/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/wwjiang007/subscriptions',
#      'organizations_url': 'https://api.github.com/users/wwjiang007/orgs',
#      'repos_url': 'https://api.github.com/users/wwjiang007/repos',
#      'events_url': 'https://api.github.com/users/wwjiang007/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/wwjiang007/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'body': '',
#     'created_at': '2019-11-29T15:25:05Z',
#     'updated_at': '2019-11-29T15:25:05Z',
#     'closed_at': None,
#     'merged_at': None,
#     'merge_commit_sha': None,
#     'assignee': None,
#     'assignees': [],
#     'requested_reviewers': [],
#     'requested_teams': [],
#     'labels': [],
#     'milestone': None,
#     'commits_url': 'https://api.github.com/repos/wwjiang007/delta/pulls/1/commits',
#     'review_comments_url': 'https://api.github.com/repos/wwjiang007/delta/pulls/1/comments',
#     'review_comment_url': 'https://api.github.com/repos/wwjiang007/delta/pulls/comments{/number}',
#     'comments_url': 'https://api.github.com/repos/wwjiang007/delta/issues/1/comments',
#     'statuses_url': 'https://api.github.com/repos/wwjiang007/delta/statuses/526cc526f79dc22f6e76f7a61a2ce4561e65da7a',
#     'head': {'label': 'delta-io:master',
#      'ref': 'master',
#      'sha': '526cc526f79dc22f6e76f7a61a2ce4561e65da7a',
#      'user': {'login': 'delta-io',
#       'id': 49767398,
#       'node_id': 'MDEyOk9yZ2FuaXphdGlvbjQ5NzY3Mzk4',
#       'avatar_url': 'https://avatars0.githubusercontent.com/u/49767398?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/delta-io',
#       'html_url': 'https://github.com/delta-io',
#       'followers_url': 'https://api.github.com/users/delta-io/followers',
#       'following_url': 'https://api.github.com/users/delta-io/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/delta-io/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/delta-io/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/delta-io/subscriptions',
#       'organizations_url': 'https://api.github.com/users/delta-io/orgs',
#       'repos_url': 'https://api.github.com/users/delta-io/repos',
#       'events_url': 'https://api.github.com/users/delta-io/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/delta-io/received_events',
#       'type': 'Organization',
#       'site_admin': False},
#      'repo': {'id': 182849188,
#       'node_id': 'MDEwOlJlcG9zaXRvcnkxODI4NDkxODg=',
#       'name': 'delta',
#       'full_name': 'delta-io/delta',
#       'private': False,
#       'owner': {'login': 'delta-io',
#        'id': 49767398,
#        'node_id': 'MDEyOk9yZ2FuaXphdGlvbjQ5NzY3Mzk4',
#        'avatar_url': 'https://avatars0.githubusercontent.com/u/49767398?v=4',
#        'gravatar_id': '',
#        'url': 'https://api.github.com/users/delta-io',
#        'html_url': 'https://github.com/delta-io',
#        'followers_url': 'https://api.github.com/users/delta-io/followers',
#        'following_url': 'https://api.github.com/users/delta-io/following{/other_user}',
#        'gists_url': 'https://api.github.com/users/delta-io/gists{/gist_id}',
#        'starred_url': 'https://api.github.com/users/delta-io/starred{/owner}{/repo}',
#        'subscriptions_url': 'https://api.github.com/users/delta-io/subscriptions',
#        'organizations_url': 'https://api.github.com/users/delta-io/orgs',
#        'repos_url': 'https://api.github.com/users/delta-io/repos',
#        'events_url': 'https://api.github.com/users/delta-io/events{/privacy}',
#        'received_events_url': 'https://api.github.com/users/delta-io/received_events',
#        'type': 'Organization',
#        'site_admin': False},
#       'html_url': 'https://github.com/delta-io/delta',
#       'description': 'An open-source storage layer that brings scalable, ACID transactions to Apache Spark™ and big data workloads.',
#       'fork': False,
#       'url': 'https://api.github.com/repos/delta-io/delta',
#       'forks_url': 'https://api.github.com/repos/delta-io/delta/forks',
#       'keys_url': 'https://api.github.com/repos/delta-io/delta/keys{/key_id}',
#       'collaborators_url': 'https://api.github.com/repos/delta-io/delta/collaborators{/collaborator}',
#       'teams_url': 'https://api.github.com/repos/delta-io/delta/teams',
#       'hooks_url': 'https://api.github.com/repos/delta-io/delta/hooks',
#       'issue_events_url': 'https://api.github.com/repos/delta-io/delta/issues/events{/number}',
#       'events_url': 'https://api.github.com/repos/delta-io/delta/events',
#       'assignees_url': 'https://api.github.com/repos/delta-io/delta/assignees{/user}',
#       'branches_url': 'https://api.github.com/repos/delta-io/delta/branches{/branch}',
#       'tags_url': 'https://api.github.com/repos/delta-io/delta/tags',
#       'blobs_url': 'https://api.github.com/repos/delta-io/delta/git/blobs{/sha}',
#       'git_tags_url': 'https://api.github.com/repos/delta-io/delta/git/tags{/sha}',
#       'git_refs_url': 'https://api.github.com/repos/delta-io/delta/git/refs{/sha}',
#       'trees_url': 'https://api.github.com/repos/delta-io/delta/git/trees{/sha}',
#       'statuses_url': 'https://api.github.com/repos/delta-io/delta/statuses/{sha}',
#       'languages_url': 'https://api.github.com/repos/delta-io/delta/languages',
#       'stargazers_url': 'https://api.github.com/repos/delta-io/delta/stargazers',
#       'contributors_url': 'https://api.github.com/repos/delta-io/delta/contributors',
#       'subscribers_url': 'https://api.github.com/repos/delta-io/delta/subscribers',
#       'subscription_url': 'https://api.github.com/repos/delta-io/delta/subscription',
#       'commits_url': 'https://api.github.com/repos/delta-io/delta/commits{/sha}',
#       'git_commits_url': 'https://api.github.com/repos/delta-io/delta/git/commits{/sha}',
#       'comments_url': 'https://api.github.com/repos/delta-io/delta/comments{/number}',
#       'issue_comment_url': 'https://api.github.com/repos/delta-io/delta/issues/comments{/number}',
#       'contents_url': 'https://api.github.com/repos/delta-io/delta/contents/{+path}',
#       'compare_url': 'https://api.github.com/repos/delta-io/delta/compare/{base}...{head}',
#       'merges_url': 'https://api.github.com/repos/delta-io/delta/merges',
#       'archive_url': 'https://api.github.com/repos/delta-io/delta/{archive_format}{/ref}',
#       'downloads_url': 'https://api.github.com/repos/delta-io/delta/downloads',
#       'issues_url': 'https://api.github.com/repos/delta-io/delta/issues{/number}',
#       'pulls_url': 'https://api.github.com/repos/delta-io/delta/pulls{/number}',
#       'milestones_url': 'https://api.github.com/repos/delta-io/delta/milestones{/number}',
#       'notifications_url': 'https://api.github.com/repos/delta-io/delta/notifications{?since,all,participating}',
#       'labels_url': 'https://api.github.com/repos/delta-io/delta/labels{/name}',
#       'releases_url': 'https://api.github.com/repos/delta-io/delta/releases{/id}',
#       'deployments_url': 'https://api.github.com/repos/delta-io/delta/deployments',
#       'created_at': '2019-04-22T18:56:51Z',
#       'updated_at': '2019-11-29T14:01:31Z',
#       'pushed_at': '2019-11-27T22:35:53Z',
#       'git_url': 'git://github.com/delta-io/delta.git',
#       'ssh_url': 'git@github.com:delta-io/delta.git',
#       'clone_url': 'https://github.com/delta-io/delta.git',
#       'svn_url': 'https://github.com/delta-io/delta',
#       'homepage': 'https://delta.io',
#       'size': 8185,
#       'stargazers_count': 1932,
#       'watchers_count': 1932,
#       'language': 'Scala',
#       'has_issues': True,
#       'has_projects': False,
#       'has_downloads': True,
#       'has_wiki': False,
#       'has_pages': False,
#       'forks_count': 374,
#       'mirror_url': None,
#       'archived': False,
#       'disabled': False,
#       'open_issues_count': 74,
#       'license': {'key': 'apache-2.0',
#        'name': 'Apache License 2.0',
#        'spdx_id': 'Apache-2.0',
#        'url': 'https://api.github.com/licenses/apache-2.0',
#        'node_id': 'MDc6TGljZW5zZTI='},
#       'forks': 374,
#       'open_issues': 74,
#       'watchers': 1932,
#       'default_branch': 'master'}},
#     'base': {'label': 'wwjiang007:master',
#      'ref': 'master',
#      'sha': '64905d8ccd2013a1b77118b1f9004aa1fe352372',
#      'user': {'login': 'wwjiang007',
#       'id': 4490759,
#       'node_id': 'MDQ6VXNlcjQ0OTA3NTk=',
#       'avatar_url': 'https://avatars0.githubusercontent.com/u/4490759?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/wwjiang007',
#       'html_url': 'https://github.com/wwjiang007',
#       'followers_url': 'https://api.github.com/users/wwjiang007/followers',
#       'following_url': 'https://api.github.com/users/wwjiang007/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/wwjiang007/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/wwjiang007/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/wwjiang007/subscriptions',
#       'organizations_url': 'https://api.github.com/users/wwjiang007/orgs',
#       'repos_url': 'https://api.github.com/users/wwjiang007/repos',
#       'events_url': 'https://api.github.com/users/wwjiang007/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/wwjiang007/received_events',
#       'type': 'User',
#       'site_admin': False},
#      'repo': {'id': 205892190,
#       'node_id': 'MDEwOlJlcG9zaXRvcnkyMDU4OTIxOTA=',
#       'name': 'delta',
#       'full_name': 'wwjiang007/delta',
#       'private': False,
#       'owner': {'login': 'wwjiang007',
#        'id': 4490759,
#        'node_id': 'MDQ6VXNlcjQ0OTA3NTk=',
#        'avatar_url': 'https://avatars0.githubusercontent.com/u/4490759?v=4',
#        'gravatar_id': '',
#        'url': 'https://api.github.com/users/wwjiang007',
#        'html_url': 'https://github.com/wwjiang007',
#        'followers_url': 'https://api.github.com/users/wwjiang007/followers',
#        'following_url': 'https://api.github.com/users/wwjiang007/following{/other_user}',
#        'gists_url': 'https://api.github.com/users/wwjiang007/gists{/gist_id}',
#        'starred_url': 'https://api.github.com/users/wwjiang007/starred{/owner}{/repo}',
#        'subscriptions_url': 'https://api.github.com/users/wwjiang007/subscriptions',
#        'organizations_url': 'https://api.github.com/users/wwjiang007/orgs',
#        'repos_url': 'https://api.github.com/users/wwjiang007/repos',
#        'events_url': 'https://api.github.com/users/wwjiang007/events{/privacy}',
#        'received_events_url': 'https://api.github.com/users/wwjiang007/received_events',
#        'type': 'User',
#        'site_admin': False},
#       'html_url': 'https://github.com/wwjiang007/delta',
#       'description': 'An open-source storage layer that brings scalable, ACID transactions to Apache Spark™ and big data workloads.',
#       'fork': True,
#       'url': 'https://api.github.com/repos/wwjiang007/delta',
#       'forks_url': 'https://api.github.com/repos/wwjiang007/delta/forks',
#       'keys_url': 'https://api.github.com/repos/wwjiang007/delta/keys{/key_id}',
#       'collaborators_url': 'https://api.github.com/repos/wwjiang007/delta/collaborators{/collaborator}',
#       'teams_url': 'https://api.github.com/repos/wwjiang007/delta/teams',
#       'hooks_url': 'https://api.github.com/repos/wwjiang007/delta/hooks',
#       'issue_events_url': 'https://api.github.com/repos/wwjiang007/delta/issues/events{/number}',
#       'events_url': 'https://api.github.com/repos/wwjiang007/delta/events',
#       'assignees_url': 'https://api.github.com/repos/wwjiang007/delta/assignees{/user}',
#       'branches_url': 'https://api.github.com/repos/wwjiang007/delta/branches{/branch}',
#       'tags_url': 'https://api.github.com/repos/wwjiang007/delta/tags',
#       'blobs_url': 'https://api.github.com/repos/wwjiang007/delta/git/blobs{/sha}',
#       'git_tags_url': 'https://api.github.com/repos/wwjiang007/delta/git/tags{/sha}',
#       'git_refs_url': 'https://api.github.com/repos/wwjiang007/delta/git/refs{/sha}',
#       'trees_url': 'https://api.github.com/repos/wwjiang007/delta/git/trees{/sha}',
#       'statuses_url': 'https://api.github.com/repos/wwjiang007/delta/statuses/{sha}',
#       'languages_url': 'https://api.github.com/repos/wwjiang007/delta/languages',
#       'stargazers_url': 'https://api.github.com/repos/wwjiang007/delta/stargazers',
#       'contributors_url': 'https://api.github.com/repos/wwjiang007/delta/contributors',
#       'subscribers_url': 'https://api.github.com/repos/wwjiang007/delta/subscribers',
#       'subscription_url': 'https://api.github.com/repos/wwjiang007/delta/subscription',
#       'commits_url': 'https://api.github.com/repos/wwjiang007/delta/commits{/sha}',
#       'git_commits_url': 'https://api.github.com/repos/wwjiang007/delta/git/commits{/sha}',
#       'comments_url': 'https://api.github.com/repos/wwjiang007/delta/comments{/number}',
#       'issue_comment_url': 'https://api.github.com/repos/wwjiang007/delta/issues/comments{/number}',
#       'contents_url': 'https://api.github.com/repos/wwjiang007/delta/contents/{+path}',
#       'compare_url': 'https://api.github.com/repos/wwjiang007/delta/compare/{base}...{head}',
#       'merges_url': 'https://api.github.com/repos/wwjiang007/delta/merges',
#       'archive_url': 'https://api.github.com/repos/wwjiang007/delta/{archive_format}{/ref}',
#       'downloads_url': 'https://api.github.com/repos/wwjiang007/delta/downloads',
#       'issues_url': 'https://api.github.com/repos/wwjiang007/delta/issues{/number}',
#       'pulls_url': 'https://api.github.com/repos/wwjiang007/delta/pulls{/number}',
#       'milestones_url': 'https://api.github.com/repos/wwjiang007/delta/milestones{/number}',
#       'notifications_url': 'https://api.github.com/repos/wwjiang007/delta/notifications{?since,all,participating}',
#       'labels_url': 'https://api.github.com/repos/wwjiang007/delta/labels{/name}',
#       'releases_url': 'https://api.github.com/repos/wwjiang007/delta/releases{/id}',
#       'deployments_url': 'https://api.github.com/repos/wwjiang007/delta/deployments',
#       'created_at': '2019-09-02T16:05:06Z',
#       'updated_at': '2019-09-02T16:05:08Z',
#       'pushed_at': '2019-08-30T11:50:05Z',
#       'git_url': 'git://github.com/wwjiang007/delta.git',
#       'ssh_url': 'git@github.com:wwjiang007/delta.git',
#       'clone_url': 'https://github.com/wwjiang007/delta.git',
#       'svn_url': 'https://github.com/wwjiang007/delta',
#       'homepage': 'https://delta.io',
#       'size': 535,
#       'stargazers_count': 0,
#       'watchers_count': 0,
#       'language': 'Scala',
#       'has_issues': False,
#       'has_projects': True,
#       'has_downloads': True,
#       'has_wiki': False,
#       'has_pages': False,
#       'forks_count': 0,
#       'mirror_url': None,
#       'archived': False,
#       'disabled': False,
#       'open_issues_count': 1,
#       'license': {'key': 'apache-2.0',
#        'name': 'Apache License 2.0',
#        'spdx_id': 'Apache-2.0',
#        'url': 'https://api.github.com/licenses/apache-2.0',
#        'node_id': 'MDc6TGljZW5zZTI='},
#       'forks': 0,
#       'open_issues': 1,
#       'watchers': 0,
#       'default_branch': 'master'}},
#     '_links': {'self': {'href': 'https://api.github.com/repos/wwjiang007/delta/pulls/1'},
#      'html': {'href': 'https://github.com/wwjiang007/delta/pull/1'},
#      'issue': {'href': 'https://api.github.com/repos/wwjiang007/delta/issues/1'},
#      'comments': {'href': 'https://api.github.com/repos/wwjiang007/delta/issues/1/comments'},
#      'review_comments': {'href': 'https://api.github.com/repos/wwjiang007/delta/pulls/1/comments'},
#      'review_comment': {'href': 'https://api.github.com/repos/wwjiang007/delta/pulls/comments{/number}'},
#      'commits': {'href': 'https://api.github.com/repos/wwjiang007/delta/pulls/1/commits'},
#      'statuses': {'href': 'https://api.github.com/repos/wwjiang007/delta/statuses/526cc526f79dc22f6e76f7a61a2ce4561e65da7a'}},
#     'author_association': 'OWNER',
#     'merged': False,
#     'mergeable': None,
#     'rebaseable': None,
#     'mergeable_state': 'unknown',
#     'merged_by': None,
#     'comments': 0,
#     'review_comments': 0,
#     'maintainer_can_modify': False,
#     'commits': 70,
#     'additions': 10749,
#     'deletions': 354,
#     'changed_files': 127}},
#   'public': True,
#   'created_at': '2019-11-29T15:25:06Z'},
#  {'id': '10976988708',
#   'type': 'PushEvent',
#   'actor': {'id': 52918236,
#    'login': 'heqixingyun',
#    'display_login': 'heqixingyun',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/heqixingyun',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/52918236?'},
#   'repo': {'id': 224872275,
#    'name': 'heqixingyun/LR02030414',
#    'url': 'https://api.github.com/repos/heqixingyun/LR02030414'},
#   'payload': {'push_id': 4336392328,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
# ...
#       'mirror_url': None,
#       'archived': False,
#       'disabled': False,
#       'open_issues_count': 71,
#       'license': {'key': 'mit',
#        'name': 'MIT License',
#        'spdx_id': 'MIT',
#        'url': 'https://api.github.com/licenses/mit',
#        'node_id': 'MDc6TGljZW5zZTEz'},
#       'forks': 635,
#       'open_issues': 71,
#       'watchers': 3312,
#       'default_branch': 'master'}},
#     '_links': {'self': {'href': 'https://api.github.com/repos/stamparm/maltrail/pulls/5275'},
#      'html': {'href': 'https://github.com/stamparm/maltrail/pull/5275'},
#      'issue': {'href': 'https://api.github.com/repos/stamparm/maltrail/issues/5275'},
#      'comments': {'href': 'https://api.github.com/repos/stamparm/maltrail/issues/5275/comments'},
#      'review_comments': {'href': 'https://api.github.com/repos/stamparm/maltrail/pulls/5275/comments'},
#      'review_comment': {'href': 'https://api.github.com/repos/stamparm/maltrail/pulls/comments{/number}'},
#      'commits': {'href': 'https://api.github.com/repos/stamparm/maltrail/pulls/5275/commits'},
#      'statuses': {'href': 'https://api.github.com/repos/stamparm/maltrail/statuses/2f765699962d44cb2543633f258c479efeff3005'}},
#     'author_association': 'CONTRIBUTOR',
#     'merged': False,
#     'mergeable': None,
#     'rebaseable': None,
#     'mergeable_state': 'unknown',
#     'merged_by': None,
#     'comments': 0,
#     'review_comments': 0,
#     'maintainer_can_modify': True,
#     'commits': 1,
#     'additions': 6,
#     'deletions': 0,
#     'changed_files': 1}},
#   'public': True,
#   'created_at': '2019-11-29T15:25:05Z'},
#  {'id': '10976988664',
#   'type': 'PushEvent',
#   'actor': {'id': 46350409,
#    'login': 'xposed73',
#    'display_login': 'xposed73',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/xposed73',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/46350409?'},
#   'repo': {'id': 224877732,
#    'name': 'XposedDevelopers/xposeddevelopers.github.io',
#    'url': 'https://api.github.com/repos/XposedDevelopers/xposeddevelopers.github.io'},
#   'payload': {'push_id': 4336392306,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': '4f691f27ec7b98af04293824b830ca0723dd8760',
#    'before': '42c34c8d8e29b10ea73bddfa08d10c0d99ddee2f',
#    'commits': [{'sha': '4f691f27ec7b98af04293824b830ca0723dd8760',
#      'author': {'email': '46350409+xposed73@users.noreply.github.com',
#       'name': 'Nadeem Khan'},
#      'message': 'Delete Readme.md',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/XposedDevelopers/xposeddevelopers.github.io/commits/4f691f27ec7b98af04293824b830ca0723dd8760'}]},
#   'public': True,
#   'created_at': '2019-11-29T15:25:05Z',
#   'org': {'id': 58337068,
#    'login': 'XposedDevelopers',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/XposedDevelopers',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/58337068?'}},
#  {'id': '10976988660',
#   'type': 'IssuesEvent',
#   'actor': {'id': 21153554,
#    'login': 'rumboalla',
#    'display_login': 'rumboalla',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/rumboalla',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/21153554?'},
#   'repo': {'id': 66190491,
#    'name': 'rumboalla/apkupdater',
#    'url': 'https://api.github.com/repos/rumboalla/apkupdater'},
#   'payload': {'action': 'closed',
#    'issue': {'url': 'https://api.github.com/repos/rumboalla/apkupdater/issues/235',
#     'repository_url': 'https://api.github.com/repos/rumboalla/apkupdater',
#     'labels_url': 'https://api.github.com/repos/rumboalla/apkupdater/issues/235/labels{/name}',
#     'comments_url': 'https://api.github.com/repos/rumboalla/apkupdater/issues/235/comments',
#     'events_url': 'https://api.github.com/repos/rumboalla/apkupdater/issues/235/events',
#     'html_url': 'https://github.com/rumboalla/apkupdater/issues/235',
#     'id': 247529364,
#     'node_id': 'MDU6SXNzdWUyNDc1MjkzNjQ=',
#     'number': 235,
#     'title': 'App does not check cache for file before downloading',
#     'user': {'login': 'rancidfrog',
#      'id': 6155036,
#      'node_id': 'MDQ6VXNlcjYxNTUwMzY=',
#      'avatar_url': 'https://avatars3.githubusercontent.com/u/6155036?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/rancidfrog',
#      'html_url': 'https://github.com/rancidfrog',
#      'followers_url': 'https://api.github.com/users/rancidfrog/followers',
#      'following_url': 'https://api.github.com/users/rancidfrog/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/rancidfrog/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/rancidfrog/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/rancidfrog/subscriptions',
#      'organizations_url': 'https://api.github.com/users/rancidfrog/orgs',
#      'repos_url': 'https://api.github.com/users/rancidfrog/repos',
#      'events_url': 'https://api.github.com/users/rancidfrog/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/rancidfrog/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'labels': [{'id': 428286933,
#       'node_id': 'MDU6TGFiZWw0MjgyODY5MzM=',
#       'url': 'https://api.github.com/repos/rumboalla/apkupdater/labels/enhancement',
#       'name': 'enhancement',
#       'color': '84b6eb',
#       'default': True,
#       'description': None}],
#     'state': 'closed',
#     'locked': False,
#     'assignee': None,
#     'assignees': [],
#     'milestone': None,
#     'comments': 3,
#     'created_at': '2017-08-02T21:33:54Z',
#     'updated_at': '2019-11-29T15:25:05Z',
#     'closed_at': '2019-11-29T15:25:05Z',
#     'author_association': 'NONE',
#     'body': 'If you click cancel instead of install, then recheck update, file gets downloaded again.\r\nThis can be repeated again and again:\r\n![](https://s4.postimg.org/9wrxie6q5/Screenshot_20170803-002343_01.png)\r\n\r\nAs seen from above, files with same size are identical.\r\nIf file is saved with package name and version code, instead of random format, then you can first check cache if file exists before downloading again.\r\n\r\nThis is not a major concern, but when using data wastes bandwidth. Also, bad practice.'}},
#   'public': True,
#   'created_at': '2019-11-29T15:25:05Z'},
#  {'id': '10976988653',
#   'type': 'CreateEvent',
#   'actor': {'id': 35588783,
#    'login': 'DHaussermann',
#    'display_login': 'DHaussermann',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/DHaussermann',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/35588783?'},
#   'repo': {'id': 121413795,
#    'name': 'DHaussermann/hello-world',
#    'url': 'https://api.github.com/repos/DHaussermann/hello-world'},
#   'payload': {'ref': 'ggg',
#    'ref_type': 'branch',
#    'master_branch': 'master',
#    'description': "Dylan's test repository",
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2019-11-29T15:25:05Z'},
#  {'id': '10976988654',
#   'type': 'PushEvent',
#   'actor': {'id': 541490,
#    'login': 'morrah',
#    'display_login': 'morrah',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/morrah',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/541490?'},
#   'repo': {'id': 224001345,
#    'name': 'morrah/oro-market',
#    'url': 'https://api.github.com/repos/morrah/oro-market'},
#   'payload': {'push_id': 4336392295,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': 'b5a8910d2e399915990041be364b383d17ed931c',
#    'before': '6ed62394523d89503b1969e141a54a02879d28c9',
#    'commits': [{'sha': 'b5a8910d2e399915990041be364b383d17ed931c',
#      'author': {'email': 'morrah@users.noreply.github.com', 'name': 'morrah'},
#      'message': 'data update',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/morrah/oro-market/commits/b5a8910d2e399915990041be364b383d17ed931c'}]},
#   'public': True,
#   'created_at': '2019-11-29T15:25:05Z'},
#  {'id': '10976988643',
#   'type': 'IssuesEvent',
#   'actor': {'id': 271950,
#    'login': 'Redth',
#    'display_login': 'Redth',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/Redth',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/271950?'},
#   'repo': {'id': 29352730,
#    'name': 'xamarin/XamarinComponents',
#    'url': 'https://api.github.com/repos/xamarin/XamarinComponents'},
#   'payload': {'action': 'closed',
#    'issue': {'url': 'https://api.github.com/repos/xamarin/XamarinComponents/issues/639',
#     'repository_url': 'https://api.github.com/repos/xamarin/XamarinComponents',
#     'labels_url': 'https://api.github.com/repos/xamarin/XamarinComponents/issues/639/labels{/name}',
#     'comments_url': 'https://api.github.com/repos/xamarin/XamarinComponents/issues/639/comments',
#     'events_url': 'https://api.github.com/repos/xamarin/XamarinComponents/issues/639/events',
#     'html_url': 'https://github.com/xamarin/XamarinComponents/issues/639',
#     'id': 480081155,
#     'node_id': 'MDU6SXNzdWU0ODAwODExNTU=',
#     'number': 639,
#     'title': 'Youtube.Player IOS can not play some videos',
#     'user': {'login': 'Ngoc-Quang',
#      'id': 26499058,
#      'node_id': 'MDQ6VXNlcjI2NDk5MDU4',
#      'avatar_url': 'https://avatars0.githubusercontent.com/u/26499058?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/Ngoc-Quang',
#      'html_url': 'https://github.com/Ngoc-Quang',
#      'followers_url': 'https://api.github.com/users/Ngoc-Quang/followers',
#      'following_url': 'https://api.github.com/users/Ngoc-Quang/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/Ngoc-Quang/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/Ngoc-Quang/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/Ngoc-Quang/subscriptions',
#      'organizations_url': 'https://api.github.com/users/Ngoc-Quang/orgs',
#      'repos_url': 'https://api.github.com/users/Ngoc-Quang/repos',
#      'events_url': 'https://api.github.com/users/Ngoc-Quang/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/Ngoc-Quang/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'labels': [{'id': 1253530543,
#       'node_id': 'MDU6TGFiZWwxMjUzNTMwNTQz',
#       'url': 'https://api.github.com/repos/xamarin/XamarinComponents/labels/upstream',
#       'name': 'upstream',
#       'color': 'b883d1',
#       'default': False,
#       'description': 'Upstream issue'}],
#     'state': 'closed',
#     'locked': False,
#     'assignee': None,
#     'assignees': [],
#     'milestone': None,
#     'comments': 3,
#     'created_at': '2019-08-13T10:31:10Z',
#     'updated_at': '2019-11-29T15:25:05Z',
#     'closed_at': '2019-11-29T15:25:04Z',
#     'author_association': 'NONE',
#     'body': 'Same as the title. After implement this library on nuget. Most of youtube link can play. But some video cannot play on IOS (Ex: video id **5eMRpJ2D8tg** )\r\n\r\nThis bug also occur on example source code.\r\nWill you have plan to fix it?\r\n\r\nThanks.'}},
#   'public': True,
#   'created_at': '2019-11-29T15:25:05Z',
#   'org': {'id': 790012,
#    'login': 'xamarin',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/xamarin',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/790012?'}},
#  {'id': '10976988652',
#   'type': 'IssuesEvent',
#   'actor': {'id': 21153554,
#    'login': 'rumboalla',
#    'display_login': 'rumboalla',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/rumboalla',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/21153554?'},
#   'repo': {'id': 66190491,
#    'name': 'rumboalla/apkupdater',
#    'url': 'https://api.github.com/repos/rumboalla/apkupdater'},
#   'payload': {'action': 'closed',
#    'issue': {'url': 'https://api.github.com/repos/rumboalla/apkupdater/issues/233',
#     'repository_url': 'https://api.github.com/repos/rumboalla/apkupdater',
#     'labels_url': 'https://api.github.com/repos/rumboalla/apkupdater/issues/233/labels{/name}',
#     'comments_url': 'https://api.github.com/repos/rumboalla/apkupdater/issues/233/comments',
#     'events_url': 'https://api.github.com/repos/rumboalla/apkupdater/issues/233/events',
#     'html_url': 'https://github.com/rumboalla/apkupdater/issues/233',
#     'id': 247325744,
#     'node_id': 'MDU6SXNzdWUyNDczMjU3NDQ=',
#     'number': 233,
#     'title': 'Show App icon on Search results',
#     'user': {'login': 'jerryn70',
#      'id': 23030460,
#      'node_id': 'MDQ6VXNlcjIzMDMwNDYw',
#      'avatar_url': 'https://avatars1.githubusercontent.com/u/23030460?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/jerryn70',
#      'html_url': 'https://github.com/jerryn70',
#      'followers_url': 'https://api.github.com/users/jerryn70/followers',
#      'following_url': 'https://api.github.com/users/jerryn70/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/jerryn70/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/jerryn70/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/jerryn70/subscriptions',
#      'organizations_url': 'https://api.github.com/users/jerryn70/orgs',
#      'repos_url': 'https://api.github.com/users/jerryn70/repos',
#      'events_url': 'https://api.github.com/users/jerryn70/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/jerryn70/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'labels': [{'id': 428286933,
#       'node_id': 'MDU6TGFiZWw0MjgyODY5MzM=',
#       'url': 'https://api.github.com/repos/rumboalla/apkupdater/labels/enhancement',
#       'name': 'enhancement',
#       'color': '84b6eb',
#       'default': True,
#       'description': None}],
#     'state': 'closed',
#     'locked': False,
#     'assignee': None,
#     'assignees': [],
#     'milestone': None,
#     'comments': 1,
#     'created_at': '2017-08-02T09:24:28Z',
#     'updated_at': '2019-11-29T15:25:05Z',
#     'closed_at': '2019-11-29T15:25:05Z',
#     'author_association': 'NONE',
#     'body': "When i search for apps ,the result shows a list of apps but it's hard to find out the real app which iam looking for because there is no app icons . "}},
#   'public': True,
#   'created_at': '2019-11-29T15:25:05Z'},
#  {'id': '10976988647',
#   'type': 'PushEvent',
#   'actor': {'id': 50364113,
#    'login': 'YiWuS',
#    'display_login': 'YiWuS',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/YiWuS',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/50364113?'},
#   'repo': {'id': 224204322,
#    'name': 'YiWuS/AutoSellTicket',
#    'url': 'https://api.github.com/repos/YiWuS/AutoSellTicket'},
#   'payload': {'push_id': 4336392290,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': 'ef37272ab26dd936ab843d272ccd323a62008584',
#    'before': '980e7fd1fe5451a4519aa944ab00a6816b55e374',
#    'commits': [{'sha': 'ef37272ab26dd936ab843d272ccd323a62008584',
#      'author': {'email': '50364113+YiWuS@users.noreply.github.com',
#       'name': 'YiWuS'},
#      'message': 'Update README.md',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/YiWuS/AutoSellTicket/commits/ef37272ab26dd936ab843d272ccd323a62008584'}]},
#   'public': True,
#   'created_at': '2019-11-29T15:25:05Z'},
#  {'id': '10976988642',
#   'type': 'PushEvent',
#   'actor': {'id': 6123962,
#    'login': 'tinmarino',
#    'display_login': 'tinmarino',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/tinmarino',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/6123962?'},
#   'repo': {'id': 216000619,
#    'name': 'tinmarino/wiki',
#    'url': 'https://api.github.com/repos/tinmarino/wiki'},
#   'payload': {'push_id': 4336392292,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': 'fed991b7bc768e819ea3add7aa5206d193e9225e',
#    'before': 'e7eabe8840f19b04a817ed37eb7f4804931087ae',
#    'commits': [{'sha': 'fed991b7bc768e819ea3add7aa5206d193e9225e',
#      'author': {'email': 'tinmarino@gmail.com', 'name': 'tinmarino'},
#      'message': '___ <- sync_wiki.sh: Modified: Cheat/Vim-Advanced.md, Js.md, Vim.md',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/tinmarino/wiki/commits/fed991b7bc768e819ea3add7aa5206d193e9225e'}]},
#   'public': True,
#   'created_at': '2019-11-29T15:25:05Z'}]

# %%
type(json.loads(r.text))
# Out:
# list

# %% [markdown]
# ### 兩者差別
# json.loads(r.text)，有JSON結構；而r.text則沒有，兩者的型態也不一樣，json.loads(r.text)是list，r.text是string

# %% [markdown]
# ### 自行尋找一個合適的 API 接口做練習，並且查看其回傳內容
#
# * https://cat-fact.herokuapp.com/facts (來源：https://alexwohlbruck.github.io/cat-facts/)
# * http://odata.wra.gov.tw/v4/RealtimeWaterLevel (來源：https://data.gov.tw/dataset/25768)

# %%
r = requests.get("http://odata.wra.gov.tw/v4/RealtimeWaterLevel")
r.text
# Out:
# '{"@odata.context": "http://odata.wra.gov.tw/v4/$metadata#RealtimeWaterLevel",\n"@odata.count": 100,\n"value": [{"StationIdentifier": "1670H004","RecordTime": "Nov 29, 2019 11:20:00 PM","WaterLevel": 2.99},{"StationIdentifier": "2420H019","RecordTime": "Nov 29, 2019 11:20:00 PM","WaterLevel": 109.97},{"StationIdentifier": "1660H012","RecordTime": "Nov 29, 2019 11:20:00 PM","WaterLevel": 0.69},{"StationIdentifier": "1590H016","RecordTime": "Nov 29, 2019 11:20:00 PM","WaterLevel": 11.2},{"StationIdentifier": "2200H029","RecordTime": "Nov 29, 2019 11:20:00 PM","WaterLevel": 145.16},{"StationIdentifier": "1650H015","RecordTime": "Nov 29, 2019 11:10:00 PM","WaterLevel": 0.68},{"StationIdentifier": "1850H004","RecordTime": "Nov 29, 2019 11:20:00 PM","WaterLevel": 72.04},{"StationIdentifier": "1580H022","RecordTime": "Nov 29, 2019 11:20:00 PM","WaterLevel": 1.25},{"StationIdentifier": "1730H043","RecordTime": "Nov 29, 2019 11:20:00 PM","WaterLevel": 23.06},{"StationIdentifier": "1850H005","RecordTime": "Nov 29, 2019 11:20:00 PM","WaterLevel": 22.1},{"StationIdentifier": "1730H077","RecordTime": "Nov 29, 2019 11:20:00 PM","WaterLevel": 740.44},{"StationIdentifier": "1630H040","RecordTime": "Nov 29, 2019 11:20:00 PM","WaterLevel": 1.74},{"StationIdentifier": "2560H024","RecordTime": "Nov 29, 2019 11:20:00 PM","WaterLevel": 202.63},{"StationIdentifier": "1430H037","RecordTime": "Nov 29, 2019 11:20:00 PM","WaterLevel": 380.47},{"StationIdentifier": "1650H013","RecordTime": "Nov 29, 2019 11:20:00 PM","WaterLevel": 5.64},{"StationIdentifier": "1740H010","RecordTime": "Nov 29, 2019 11:20:00 PM","WaterLevel": 47.05},{"StationIdentifier": "1730H072","RecordTime": "Nov 29, 2019 11:20:00 PM","WaterLevel": 248.86},{"StationIdentifier": "1510H082","RecordTime": "Nov 29, 2019 11:20:00 PM","WaterLevel": 752.39},{"StationIdentifier": "2500H003","RecordTime": "Nov 29, 2019 11:20:00 PM","WaterLevel": 32.07},{"StationIdentifier": "2200H026","RecordTime": "Nov 29, 2019 11:20:00 PM","WaterLevel": 106.73},{"StationIdentifier": "1430H030","RecordTime": "Nov 29, 2019 11:20:00 PM","WaterLevel": 87.54},{"StationIdentifier": "1540H032","RecordTime": "Nov 29, 2019 11:20:00 PM","WaterLevel": 20.21},{"StationIdentifier": "1730H070","RecordTime": "Nov 29, 2019 11:20:00 PM","WaterLevel": 226.2},{"StationIdentifier": "1730H045","RecordTime": "Nov 29, 2019 11:20:00 PM","WaterLevel": 5.12},{"StationIdentifier": "1510H058","RecordTime": "Nov 29, 2019 11:10:00 PM","WaterLevel": 12.2},{"StationIdentifier": "1650H009","RecordTime": "Nov 29, 2019 11:20:00 PM","WaterLevel": 0.78},{"StationIdentifier": "2200H025","RecordTime": "Nov 29, 2019 11:20:00 PM","WaterLevel": 207.14},{"StationIdentifier": "1430H028","RecordTime": "Nov 29, 2019 11:20:00 PM","WaterLevel": 23.58},{"StationIdentifier": "1540H029","RecordTime": "Nov 29, 2019 11:20:00 PM","WaterLevel": 12.78},{"StationIdentifier": "1580H021","RecordTime": "Nov 29, 2019 11:20:00 PM","WaterLevel": 1.26},{"StationIdentifier": "1680H005","RecordTime": "Nov 29, 2019 11:20:00 PM","WaterLevel": 0.47},{"StationIdentifier": "1510H050","RecordTime": "Nov 29, 2019 11:10:00 PM","WaterLevel": 155.51},{"StationIdentifier": "1630H024","RecordTime": "Nov 29, 2019 11:20:00 PM","WaterLevel": 69.12},{"StationIdentifier": "1420H057","RecordTime": "Nov 29, 2019 11:20:00 PM","WaterLevel": 639.38},{"StationIdentifier": "2200H020","RecordTime": "Nov 29, 2019 11:20:00 PM","WaterLevel": 318.16},{"StationIdentifier": "1510H084","RecordTime": "Nov 29, 2019 11:20:00 PM","WaterLevel": 145.01},{"StationIdentifier": "1580H017","RecordTime": "Nov 29, 2019 11:20:00 PM","WaterLevel": 25.74},{"StationIdentifier": "1550H012","RecordTime": "Nov 29, 2019 11:20:00 PM","WaterLevel": 0.6},{"StationIdentifier": "1430H061","RecordTime": "Nov 29, 2019 11:20:00 PM","WaterLevel": 25},{"StationIdentifier": "1430H054","RecordTime": "Nov 29, 2019 11:20:00 PM","WaterLevel": 48.26},{"StationIdentifier": "1400H018","RecordTime": "Nov 29, 2019 11:20:00 PM","WaterLevel": 55.22 ...

# %%
json.loads(r.text)
# Out:
# {'@odata.context': 'http://odata.wra.gov.tw/v4/$metadata#RealtimeWaterLevel',
#  '@odata.count': 100,
#  'value': [{'StationIdentifier': '1670H004',
#    'RecordTime': 'Nov 29, 2019 11:20:00 PM',
#    'WaterLevel': 2.99},
#   {'StationIdentifier': '2420H019',
#    'RecordTime': 'Nov 29, 2019 11:20:00 PM',
#    'WaterLevel': 109.97},
#   {'StationIdentifier': '1660H012',
#    'RecordTime': 'Nov 29, 2019 11:20:00 PM',
#    'WaterLevel': 0.69},
#   {'StationIdentifier': '1590H016',
#    'RecordTime': 'Nov 29, 2019 11:20:00 PM',
#    'WaterLevel': 11.2},
#   {'StationIdentifier': '2200H029',
#    'RecordTime': 'Nov 29, 2019 11:20:00 PM',
#    'WaterLevel': 145.16},
#   {'StationIdentifier': '1650H015',
#    'RecordTime': 'Nov 29, 2019 11:10:00 PM',
#    'WaterLevel': 0.68},
#   {'StationIdentifier': '1850H004',
#    'RecordTime': 'Nov 29, 2019 11:20:00 PM',
#    'WaterLevel': 72.04},
#   {'StationIdentifier': '1580H022',
#    'RecordTime': 'Nov 29, 2019 11:20:00 PM',
#    'WaterLevel': 1.25},
#   {'StationIdentifier': '1730H043',
#    'RecordTime': 'Nov 29, 2019 11:20:00 PM',
#    'WaterLevel': 23.06},
#   {'StationIdentifier': '1850H005',
#    'RecordTime': 'Nov 29, 2019 11:20:00 PM',
#    'WaterLevel': 22.1},
#   {'StationIdentifier': '1730H077',
#    'RecordTime': 'Nov 29, 2019 11:20:00 PM',
#    'WaterLevel': 740.44},
#   {'StationIdentifier': '1630H040',
#    'RecordTime': 'Nov 29, 2019 11:20:00 PM',
#    'WaterLevel': 1.74},
#   {'StationIdentifier': '2560H024',
#    'RecordTime': 'Nov 29, 2019 11:20:00 PM',
#    'WaterLevel': 202.63},
#   {'StationIdentifier': '1430H037',
#    'RecordTime': 'Nov 29, 2019 11:20:00 PM',
#    'WaterLevel': 380.47},
#   {'StationIdentifier': '1650H013',
#    'RecordTime': 'Nov 29, 2019 11:20:00 PM',
#    'WaterLevel': 5.64},
#   {'StationIdentifier': '1740H010',
#    'RecordTime': 'Nov 29, 2019 11:20:00 PM',
#    'WaterLevel': 47.05},
#   {'StationIdentifier': '1730H072',
#    'RecordTime': 'Nov 29, 2019 11:20:00 PM',
#    'WaterLevel': 248.86},
#   {'StationIdentifier': '1510H082',
#    'RecordTime': 'Nov 29, 2019 11:20:00 PM',
#    'WaterLevel': 752.39},
#   {'StationIdentifier': '2500H003',
#    'RecordTime': 'Nov 29, 2019 11:20:00 PM',
#    'WaterLevel': 32.07},
#   {'StationIdentifier': '2200H026',
#    'RecordTime': 'Nov 29, 2019 11:20:00 PM',
#    'WaterLevel': 106.73},
#   {'StationIdentifier': '1430H030',
#    'RecordTime': 'Nov 29, 2019 11:20:00 PM',
#    'WaterLevel': 87.54},
#   {'StationIdentifier': '1540H032',
#    'RecordTime': 'Nov 29, 2019 11:20:00 PM',
#    'WaterLevel': 20.21},
#   {'StationIdentifier': '1730H070',
#    'RecordTime': 'Nov 29, 2019 11:20:00 PM',
#    'WaterLevel': 226.2},
#   {'StationIdentifier': '1730H045',
#    'RecordTime': 'Nov 29, 2019 11:20:00 PM',
#    'WaterLevel': 5.12},
#   {'StationIdentifier': '1510H058',
#    'RecordTime': 'Nov 29, 2019 11:10:00 PM',
#    'WaterLevel': 12.2},
#   {'StationIdentifier': '1650H009',
#    'RecordTime': 'Nov 29, 2019 11:20:00 PM',
#    'WaterLevel': 0.78},
#   {'StationIdentifier': '2200H025',
#    'RecordTime': 'Nov 29, 2019 11:20:00 PM',
#    'WaterLevel': 207.14},
#   {'StationIdentifier': '1430H028',
#    'RecordTime': 'Nov 29, 2019 11:20:00 PM',
#    'WaterLevel': 23.58},
#   {'StationIdentifier': '1540H029',
#    'RecordTime': 'Nov 29, 2019 11:20:00 PM',
#    'WaterLevel': 12.78},
#   {'StationIdentifier': '1580H021',
#    'RecordTime': 'Nov 29, 2019 11:20:00 PM',
#    'WaterLevel': 1.26},
#   {'StationIdentifier': '1680H005',
#    'RecordTime': 'Nov 29, 2019 11:20:00 PM',
#    'WaterLevel': 0.47},
#   {'StationIdentifier': '1510H050',
#    'RecordTime': 'Nov 29, 2019 11:10:00 PM',
#    'WaterLevel': 155.51},
#   {'StationIdentifier': '1630H024',
#    'RecordTime': 'Nov 29, 2019 11:20:00 PM',
#    'WaterLevel': 69.12},
#   {'StationIdentifier': '1420H057',
#    'RecordTime': 'Nov 29, 2019 11:20:00 PM',
#    'WaterLevel': 639.38},
#   {'StationIdentifier': '2200H020',
#    'RecordTime': 'Nov 29, 2019 11:20:00 PM',
#    'WaterLevel': 318.16},
#   {'StationIdentifier': '1510H084',
#    'RecordTime': 'Nov 29, 2019 11:20:00 PM',
#    'WaterLevel': 145.01},
#   {'StationIdentifier': '1580H017',
#    'RecordTime': 'Nov 29, 2019 11:20:00 PM',
#    'WaterLevel': 25.74},
#   {'StationIdentifier': '1550H012',
#    'RecordTime': 'Nov 29, 2019 11:20:00 PM',
#    'WaterLevel': 0.6},
#   {'StationIdentifier': '1430H061',
#    'RecordTime': 'Nov 29, 2019 11:20:00 PM',
#    'WaterLevel': 25},
#   {'StationIdentifier': '1430H054',
#    'RecordTime': 'Nov 29, 2019 11:20:00 PM',
#    'WaterLevel': 48.26},
#   {'StationIdentifier': '1400H018',
#    'RecordTime': 'Nov 29, 2019 11:20:00 PM',
#    'WaterLevel': 55.22},
#   {'StationIdentifier': '1630H005',
#    'RecordTime': 'Nov 29, 2019 11:20:00 PM',
#    'WaterLevel': 39.77},
#   {'StationIdentifier': '1510H080',
#    'RecordTime': 'Nov 29, 2019 11:20:00 PM',
#    'WaterLevel': 1068.95},
#   {'StationIdentifier': '1580H001',
#    'RecordTime': 'Nov 29, 2019 11:20:00 PM',
#    'WaterLevel': 224.2},
#   {'StationIdentifier': '1540H030',
#    'RecordTime': 'Nov 29, 2019 11:20:00 PM',
#    'WaterLevel': 27.18},
#   {'StationIdentifier': '1430H056',
#    'RecordTime': 'Nov 29, 2019 11:20:00 PM',
#    'WaterLevel': 79.82},
#   {'StationIdentifier': '1430H051',
#    'RecordTime': 'Nov 29, 2019 11:20:00 PM',
#    'WaterLevel': 95.65},
#   {'StationIdentifier': '1400H009',
#    'RecordTime': 'Nov 29, 2019 11:20:00 PM',
#    'WaterLevel': 191.55},
#   {'StationIdentifier': '1590H013',
#    'RecordTime': 'Nov 29, 2019 11:20:00 PM',
#    'WaterLevel': 20.75},
#   {'StationIdentifier': '1510H079',
#    'RecordTime': 'Nov 29, 2019 11:10:00 PM',
#    'WaterLevel': 187.72},
#   {'StationIdentifier': '1550H014',
#    'RecordTime': 'Nov 29, 2019 11:20:00 PM',
#    'WaterLevel': 26.76},
#   {'StationIdentifier': '1540H009',
#    'RecordTime': 'Nov 29, 2019 11:20:00 PM',
#    'WaterLevel': 0.97},
#   {'StationIdentifier': '1430H045',
#    'RecordTime': 'Nov 29, 2019 11:20:00 PM',
#    'WaterLevel': 91.66},
#   {'StationIdentifier': '1430H047',
#    'RecordTime': 'Nov 29, 2019 11:20:00 PM',
#    'WaterLevel': 72.38},
#   {'StationIdentifier': '1140H108',
#    'RecordTime': 'Nov 29, 2019 11:20:00 PM',
#    'WaterLevel': 12.24},
#   {'StationIdentifier': '1580H018',
#    'RecordTime': 'Nov 29, 2019 11:20:00 PM',
#    'WaterLevel': 21.23},
#   {'StationIdentifier': '1510H071',
#    'RecordTime': 'Nov 29, 2019 11:10:00 PM',
#    'WaterLevel': 20.59},
#   {'StationIdentifier': '1540H039',
#    'RecordTime': 'Nov 29, 2019 11:20:00 PM',
#    'WaterLevel': 39},
#   {'StationIdentifier': '1520H008',
#    'RecordTime': 'Nov 29, 2019 11:20:00 PM',
#    'WaterLevel': 78.22},
#   {'StationIdentifier': '1430H040',
#    'RecordTime': 'Nov 29, 2019 11:20:00 PM',
#    'WaterLevel': 19.43},
#   {'StationIdentifier': '1420H058',
#    'RecordTime': 'Nov 29, 2019 11:20:00 PM',
#    'WaterLevel': 440.49},
#   {'StationIdentifier': '1140H082',
#    'RecordTime': 'Nov 29, 2019 11:10:00 PM',
#    'WaterLevel': 7.03},
#   {'StationIdentifier': '1580H008',
#    'RecordTime': 'Nov 29, 2019 11:20:00 PM',
#    'WaterLevel': 19.4},
#   {'StationIdentifier': '1420H055',
#    'RecordTime': 'Nov 29, 2019 11:20:00 PM',
#    'WaterLevel': 318.52},
#   {'StationIdentifier': '1540H037',
#    'RecordTime': 'Nov 29, 2019 11:20:00 PM',
#    'WaterLevel': 32.01},
#   {'StationIdentifier': '1510H086',
#    'RecordTime': 'Nov 29, 2019 11:20:00 PM',
#    'WaterLevel': 317.97},
#   {'StationIdentifier': '1310H001',
#    'RecordTime': 'Nov 29, 2019 11:20:00 PM',
#    'WaterLevel': 13.66},
#   {'StationIdentifier': '1430H058',
#    'RecordTime': 'Nov 29, 2019 11:20:00 PM',
#    'WaterLevel': 83.03},
#   {'StationIdentifier': '1140H106',
#    'RecordTime': 'Nov 29, 2019 11:20:00 PM',
#    'WaterLevel': 49.12},
#   {'StationIdentifier': '1140H049',
#    'RecordTime': 'Nov 29, 2019 11:10:00 PM',
#    'WaterLevel': 22.11},
#   {'StationIdentifier': '1540H033',
#    'RecordTime': 'Nov 29, 2019 11:20:00 PM',
#    'WaterLevel': 23.3},
#   {'StationIdentifier': '1550H017',
#    'RecordTime': 'Nov 29, 2019 11:20:00 PM',
#    'WaterLevel': 15.72},
#   {'StationIdentifier': '1510H075',
#    'RecordTime': 'Nov 29, 2019 11:10:00 PM',
#    'WaterLevel': 346.52},
#   {'StationIdentifier': '1300H022',
#    'RecordTime': 'Nov 29, 2019 11:20:00 PM',
#    'WaterLevel': 1.29},
#   {'StationIdentifier': '1340H011',
#    'RecordTime': 'Nov 29, 2019 11:20:00 PM',
#    'WaterLevel': 7.34},
#   {'StationIdentifier': '1140H099',
#    'RecordTime': 'Nov 29, 2019 11:20:00 PM',
#    'WaterLevel': 263.77},
#   {'StationIdentifier': '2560H023',
#    'RecordTime': 'Nov 29, 2019 11:20:00 PM',
#    'WaterLevel': 13.05},
#   {'StationIdentifier': '1350H031',
#    'RecordTime': 'Nov 29, 2019 11:20:00 PM',
#    'WaterLevel': 1.71},
#   {'StationIdentifier': '1420H054',
#    'RecordTime': 'Nov 29, 2019 11:20:00 PM',
#    'WaterLevel': 704.2},
#   {'StationIdentifier': '1350H022',
#    'RecordTime': 'Nov 29, 2019 11:20:00 PM',
#    'WaterLevel': 253.91},
#   {'StationIdentifier': '1290H002',
#    'RecordTime': 'Nov 29, 2019 11:20:00 PM',
#    'WaterLevel': 40.94},
#   {'StationIdentifier': '1420H049',
#    'RecordTime': 'Nov 29, 2019 11:20:00 PM',
#    'WaterLevel': 54.11},
#   {'StationIdentifier': '2560H020',
#    'RecordTime': 'Nov 29, 2019 11:20:00 PM',
#    'WaterLevel': 0.11},
#   {'StationIdentifier': '2420H036',
#    'RecordTime': 'Nov 29, 2019 11:20:00 PM',
#    'WaterLevel': 164.36},
#   {'StationIdentifier': '1350H029',
#    'RecordTime': 'Nov 29, 2019 11:20:00 PM',
#    'WaterLevel': 175.93},
#   {'StationIdentifier': '1300H023',
#    'RecordTime': 'Nov 29, 2019 11:20:00 PM',
#    'WaterLevel': 52.22},
#   {'StationIdentifier': '1350H018',
#    'RecordTime': 'Nov 29, 2019 11:20:00 PM',
#    'WaterLevel': 282.04},
#   {'StationIdentifier': '1140H128',
#    'RecordTime': 'Nov 29, 2019 11:20:00 PM',
#    'WaterLevel': 22.04},
#   {'StationIdentifier': '1400H015',
#    'RecordTime': 'Nov 29, 2019 11:20:00 PM',
#    'WaterLevel': -999998},
#   {'StationIdentifier': '2560H019',
#    'RecordTime': 'Nov 29, 2019 11:20:00 PM',
#    'WaterLevel': 4.44},
#   {'StationIdentifier': '2370H025',
#    'RecordTime': 'Nov 29, 2019 11:20:00 PM',
#    'WaterLevel': 261.61},
#   {'StationIdentifier': '1350H027',
#    'RecordTime': 'Nov 29, 2019 11:20:00 PM',
#    'WaterLevel': 145.84},
#   {'StationIdentifier': '1300H020',
#    'RecordTime': 'Nov 29, 2019 11:20:00 PM',
#    'WaterLevel': 251.43},
#   {'StationIdentifier': '1350H001',
#    'RecordTime': 'Nov 29, 2019 11:20:00 PM',
#    'WaterLevel': 169.79},
#   {'StationIdentifier': '1650H010',
#    'RecordTime': 'Nov 29, 2019 11:20:00 PM',
#    'WaterLevel': 0.85},
#   {'StationIdentifier': '1300H016',
#    'RecordTime': 'Nov 29, 2019 11:20:00 PM',
#    'WaterLevel': 100.36},
#   {'StationIdentifier': '1650H012',
#    'RecordTime': 'Nov 29, 2019 11:20:00 PM',
#    'WaterLevel': 0.8},
#   {'StationIdentifier': '2370H017',
#    'RecordTime': 'Nov 29, 2019 11:20:00 PM',
#    'WaterLevel': 58.48},
#   {'StationIdentifier': '1350H020',
#    'RecordTime': 'Nov 29, 2019 11:20:00 PM',
#    'WaterLevel': 220.79},
#   {'StationIdentifier': '1350H025',
#    'RecordTime': 'Nov 29, 2019 11:20:00 PM',
#    'WaterLevel': 1.79}],
#  '@odata.nextLink': 'http://odata.wra.gov.tw/v4/RealtimeWaterLevel?$skip=100&$top=100'}
