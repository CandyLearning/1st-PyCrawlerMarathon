# %% [markdown]
# # PTT 網路爬蟲實作練習
#
#
# * 能夠利用 Request + BeatifulSour 撰寫爬蟲，並存放到合適的資料結構

# %% [markdown]
# ## 作業目標
#
# 根據範例 ，完成以下問題：
#
# * ① 印出最新文章的「作者」「標題」「時間」
# * ② 印出第一頁所有文章的「作者」「標題」「時間」

# %% [markdown]
# ### ① 印出最新文章的「作者」「標題」「時間」

# %%
import requests
from bs4 import BeautifulSoup
def printData(url):
    r = requests.get(url)
    soup = BeautifulSoup(r.text, 'html5lib')
    for d in soup.find_all(class_ = 'title'):
        print('標題:', d.text.replace('\t', '').replace('\n', ''))
        try:
            r = BeautifulSoup(requests.get('https://www.ptt.cc' + d.find('a')['href']).text, 'html5lib')
            metalines = r.find_all(class_ = 'article-metaline')
            print('作者:', metalines[0].find(class_ = 'article-meta-value').text)
            print('時間:', metalines[2].find(class_ = 'article-meta-value').text)
            print()
        except:
            print()
            continue

printData('https://www.ptt.cc/bbs/NBA/index.html')
# Out:
# 標題: [情報] ★今日排名(2019.12.09)★
#
# 標題: [討論] 快艇替補這麼猛是在哈羅？
# 作者: hhll5566 (忽溜56)
# 時間: Mon Dec  9 21:23:35 2019
#
# 標題: (已被Vedan刪除) <maxknife>1-1(150)
#
# 標題: [討論] 太空鹿是不是飛天了  保底東冠?
# 作者: takizawahide (Val Valentino)
# 時間: Mon Dec  9 21:41:08 2019
#
# 標題: [花邊] 林書豪罰球絕殺有爭議 最後0.6秒遭誤判沒
# 作者: GhostFather (鬼父Oni Chichi)
# 時間: Mon Dec  9 22:00:42 2019
#
# 標題: (已被Vedan刪除) <icpolonaise>1-1(150)
#
# 標題: [討論] 湖人是不是需要 Plan B?
# 作者: Expiation (Expiation)
# 時間: Mon Dec  9 22:44:58 2019
#
# 標題: [新聞] 改寫前輩全能紀錄 唐西奇：喬丹無人能比
# 作者: hide0325 (hide)
# 時間: Mon Dec  9 23:07:52 2019
#
# 標題: (已被Vedan刪除) <KobebetterMJ>1-1 1-2
#
# 標題: [新聞] 尼克高層保飯碗做交易？ 傳鎖定德羅展、
# 作者: Gotham (萬惡之城)
# 時間: Mon Dec  9 23:58:17 2019
#
# 標題: [花邊] 林書豪0秒「靜態絕殺」 經典一球讓球迷
# 作者: jack8587 (james)
# 時間: Tue Dec 10 00:06:13 2019
#
# 標題: Re: [新聞] 改寫前輩全能紀錄 唐西奇：喬丹無人能比
# 作者: MrSatan (老大!!!!!!!!)
# 時間: Tue Dec 10 00:10:05 2019
#
# 標題: [討論] 熱火怎麼出乎意料的強
# 作者: g3322023 (1219_喜德)
# 時間: Tue Dec 10 00:40:02 2019
#
# 標題: [公告] 板規v6.6
#
# 標題: [公告] 樂透取消及未來不再開啟樂透
# ...

# %% [markdown]
# ### ② 印出第一頁所有文章的「作者」「標題」「時間」

# %%
printData('https://www.ptt.cc/bbs/NBA/index1.html')
# Out:
# 標題: [轉錄]Lyotard 對於太陽板討論串的結論
# 作者: Price (Price)
# 時間: Sun May 16 01:54:33 2004
#
# 標題: [公告] 請停止一切關於本次活動的發言
# 作者: Price (Price)
# 時間: Mon May 24 00:43:00 2004
#
# 標題: [轉錄]跟之前那篇比起來 我覺得這篇也應該轉過來
# 作者: Frankaze (神采風華)
# 時間: Tue Jun  8 01:16:45 2004
#
# 標題: [轉錄]再轉一篇好文來
# 作者: Frankaze (神采風華)
# 時間: Tue Jun  8 09:02:23 2004
#
# 標題: [轉錄][情報] 夏洛特山貓系列
# 作者: Price (Price)
# 時間: Thu Jun 10 00:39:35 2004
#
# 標題: [轉錄]Re: [心得] 真是受不了糗爺....
# 作者: Price (Price)
# 時間: Thu Jun 10 00:51:35 2004
#
# 標題: [轉錄]總冠軍賽NO.2觀後感
# 作者: Price (Price)
# 時間: Thu Jun 10 12:05:07 2004
#
# 標題: [心得] Rasheed Wallace
# 作者: AmuroNamie (原來太嗨真的會失眠^___^)
# 時間: Fri Jun 11 15:06:09 2004
#
# 標題: 掌控球賽的男人
# 作者: toptree (  )
# 時間: Sat Jun 12 07:13:04 2004
#
# 標題: [閒聊] 說說2004季後賽名場面回顧
# 作者: skchang (3EB板開板囉！)
# 時間: Sat Jun 12 13:21:49 2004
#
# 標題: [心得] 其實說穿了 就是活塞的防守太可怕了
# 作者: shineup ()
# 時間: Sat Jun 12 13:12:47 2004
#
# 標題: Re: [閒聊] 說說2004季後賽名場面回顧
# 作者: cOvi (喵~)
# 時間: Sat Jun 12 16:43:07 2004
#
# 標題: Re: [閒聊] 說說2004季後賽名場面回顧
# ...

# %% [markdown]
# ### ③ 試著爬爬看其他版的文章

# %%
# 閒聊版
printData('https://www.ptt.cc/bbs/C_Chat/index.html')
# Out:
# 標題: Re: [閒聊] 鬼滅 繼國兄弟
# 作者: akanokuruma (只想放空)
# 時間: Tue Dec 10 00:21:00 2019
#
# 標題: [閒聊] 看高分少女後，會想玩格鬥遊戲嗎?
# 作者: kikiki37 (441)
# 時間: Tue Dec 10 00:21:50 2019
#
# 標題: [閒聊] 身為四派，對春場劇情編排的抱怨
# 作者: aleezible (眼鏡貓)
# 時間: Tue Dec 10 00:22:32 2019
#
# 標題: [閒聊] 楓之谷官方粉絲團的一張圖
# 作者: mushrimp5466 (吃了蝦子的蘑菇)
# 時間: Tue Dec 10 00:22:49 2019
#
# 標題: [情報] 超電磁砲T OP by fripSide 2/26發售
# 作者: HMKRL (HMKRL)
# 時間: Tue Dec 10 00:24:45 2019
#
# 標題: [閒聊] 賀五等份開獎！送FGO台帳囉！
# 作者: w1230319 (龜山金城武)
# 時間: Tue Dec 10 00:26:04 2019
#
# 標題: [閒聊] 如果讓喬治RR馬丁來寫五等分
# 作者: owo0204 (owo0204)
# 時間: Tue Dec 10 00:27:39 2019
#
# 標題: [閒聊] 其實春場沒有用64拆67....
# 作者: nutssummer (煎粿一下)
# 時間: Tue Dec 10 00:29:49 2019
#
# 標題: Re: [閒聊] 與傳說寶可夢邂逅
# 作者: s50189 (咕嚕米)
# 時間: Tue Dec 10 00:30:33 2019
#
# 標題: [閒聊] 如果有統神八奇要怎麼選?
# 作者: dearbarry (莫言悲)
# 時間: Tue Dec 10 00:40:58 2019
#
# 標題: [情報] 金球獎最佳動畫長片入圍名單
# 作者: dragon803 (好想去露營啊~)
# 時間: Tue Dec 10 00:41:27 2019
#
# 標題: [閒聊] 六道的惡女 168
# 作者: chshsnail (工程師蝸牛)
# 時間: Tue Dec 10 00:41:51 2019
#
# ...
